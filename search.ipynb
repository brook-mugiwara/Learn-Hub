# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# YouTube Data API key
API_KEY = "AIzaSyCpfhlB_dGax__GBDs3SnPFFFBDZIi4Uc8"

# Function to search for videos based on a search query
def search_videos(query, api_key):
    youtube = build('youtube', 'v3', developerKey=api_key)
    videos = []
    nextPageToken = None
    while True:
        try:
            response = youtube.search().list(
                q=query,
                part='snippet',
                type='video',
                maxResults=50,  # Maximum number of results per page (adjust as needed)
                pageToken=nextPageToken
            ).execute()
            for item in response['items']:
                video_id = item['id']['videoId']
                video_url = f"https://www.youtube.com/watch?v={video_id}"
                videos.append(video_url)
            nextPageToken = response.get('nextPageToken')
            if not nextPageToken:
                break
        except HttpError as e:
            print("An HTTP error %d occurred:\n%s" % (e.resp.status, e.content))
            break
    return videos

# Main function
def main():
    search_query = input("Enter the search query: ")
    videos = search_videos(search_query, API_KEY)
    if videos:
        print("Videos found based on the search query:")
        for video in videos:
            print(video)
    else:
        print("No videos found for the provided search query.")

if __name__ == "__main__":
    main()
# Out:
# Videos found based on the search query:
# https://www.youtube.com/watch?v=Ozu7wYzxb6I
# https://www.youtube.com/watch?v=yCC8x4fLd30
# https://www.youtube.com/watch?v=OFuHbyJYq6Y
# https://www.youtube.com/watch?v=puEhbfMtchA
# https://www.youtube.com/watch?v=THUnS71mByc
# https://www.youtube.com/watch?v=HZGCoVF3YvM
# https://www.youtube.com/watch?v=KzfWUEJjG18
# https://www.youtube.com/watch?v=KoL-upN8CYw
# https://www.youtube.com/watch?v=8hwfyvjcNhM
# https://www.youtube.com/watch?v=OXfECwkl7Dc
# https://www.youtube.com/watch?v=ZA4JkHKZM50
# https://www.youtube.com/watch?v=lZSL7Tm5ViA
# https://www.youtube.com/watch?v=XZ4rk2VgaLw
# https://www.youtube.com/watch?v=8idr1WZ1A7Q
# https://www.youtube.com/watch?v=bjFbDbvMEcc
# https://www.youtube.com/watch?v=mYbdGLnTd4c
# https://www.youtube.com/watch?v=7mK0UEECObE
# https://www.youtube.com/watch?v=i67tTyfFw-A
# https://www.youtube.com/watch?v=SkidyDQuupA
# https://www.youtube.com/watch?v=b7vUhDcH2hU
# ...

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError


# Function to mimic YouTube search behavior
def youtube_search(query, api_key):
    youtube = build('youtube', 'v3', developerKey=api_key)
    videos = []
    nextPageToken = None
    while True:
        try:
            response = youtube.search().list(
                q=query,
                part='snippet',
                type='video',
                maxResults=10,  # Maximum number of results per page (adjust as needed)
                pageToken=nextPageToken,
                order='relevance'  # Sort by relevance
            ).execute()
            for item in response['items']:
                video_id = item['id']['videoId']
                video_url = f"https://www.youtube.com/watch?v={video_id}"
                videos.append(video_url)
            nextPageToken = response.get('nextPageToken')
            if not nextPageToken:
                break
        except HttpError as e:
            print("An HTTP error %d occurred:\n%s" % (e.resp.status, e.content))
            break
    return videos

# Main function
def main():
    search_query = input("Enter the search query: ")
    videos = youtube_search(search_query, API_KEY)
    if videos:
        print("Videos found based on the search query:")
        for idx, video in enumerate(videos, start=1):
            print(f"{idx}. {video}")
    else:
        print("No videos found for the provided search query.")

if __name__ == "__main__":
    main()
# Out:
# Videos found based on the search query:
# 1. https://www.youtube.com/watch?v=yCC8x4fLd30
# 2. https://www.youtube.com/watch?v=Ozu7wYzxb6I
# 3. https://www.youtube.com/watch?v=OFuHbyJYq6Y
# 4. https://www.youtube.com/watch?v=THUnS71mByc
# 5. https://www.youtube.com/watch?v=lZSL7Tm5ViA
# 6. https://www.youtube.com/watch?v=HZGCoVF3YvM
# 7. https://www.youtube.com/watch?v=KzfWUEJjG18
# 8. https://www.youtube.com/watch?v=KoL-upN8CYw
# 9. https://www.youtube.com/watch?v=2Th-zRcQ7B8
# 10. https://www.youtube.com/watch?v=ZA4JkHKZM50
# 11. https://www.youtube.com/watch?v=ZA4JkHKZM50
# 12. https://www.youtube.com/watch?v=XZ4rk2VgaLw
# 13. https://www.youtube.com/watch?v=lZSL7Tm5ViA
# 14. https://www.youtube.com/watch?v=mYbdGLnTd4c
# 15. https://www.youtube.com/watch?v=7mK0UEECObE
# 16. https://www.youtube.com/watch?v=bjFbDbvMEcc
# 17. https://www.youtube.com/watch?v=8idr1WZ1A7Q
# 18. https://www.youtube.com/watch?v=i67tTyfFw-A
# 19. https://www.youtube.com/watch?v=SkidyDQuupA
# ...
